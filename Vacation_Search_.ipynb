# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps
import numpy as np
from datetime import datetime
from citipy import citipy
import timeit
import json
import matplotlib.pyplot as plt
import requests
from config import weather_api_key
from datetime import datetime
from citipy import citipy

# Import API key
from config import g_key

# Configure gmaps API key
gmaps.configure(api_key = g_key)

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# %%
x = lats
y = lngs

# %%
# Unpack the zip in a list 
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the lats and lngs to a list
coordinates = list(lat_lngs)

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Get the nearest city using the citipy module
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
coordinates = zip(x, y)
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 734

# %%
# Starting URL for Weather Map API Call
url= "https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=" + weather_api_key

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
          
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
        
    # Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
       
    #Add 1 to the record count
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather['weather'][0]['description']
        
        # Convert the date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information to the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description":description })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | atar
# Processing Record 2 of Set 1 | alice springs
# Processing Record 3 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 1 | jamestown
# Processing Record 5 of Set 1 | livani
# Processing Record 6 of Set 1 | mardin
# Processing Record 7 of Set 1 | berlevag
# Processing Record 8 of Set 1 | paucartambo
# City not found. Skipping...
# Processing Record 9 of Set 1 | sakaiminato
# Processing Record 10 of Set 1 | havre-saint-pierre
# Processing Record 11 of Set 1 | kavieng
# Processing Record 12 of Set 1 | nanortalik
# Processing Record 13 of Set 1 | port alfred
# Processing Record 14 of Set 1 | hilo
# Processing Record 15 of Set 1 | port elizabeth
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | hermanus
# Processing Record 18 of Set 1 | laguna
# Processing Record 19 of Set 1 | thompson
# Processing Record 20 of Set 1 | airai
# Processing Record 21 of Set 1 | dikson
# Processing Record 22 of Set 1 | touros
# Processing Record 23 of Set 1 | coahuayana
# Processing Record 24 of Set 1 | vaini
# Processing Record 25 of Set 1 | kinsale
# Processing Record 26 of Set 1 | bubaque
# Processing Record 27 of Set 1 | sangar
# Processing Record 28 of Set 1 | busselton
# Processing Record 29 of Set 1 | concepcion
# Processing Record 30 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 31 of Set 1 | sao filipe
# Processing Record 32 of Set 1 | bredasdorp
# Processing Record 33 of Set 1 | atuona
# Processing Record 34 of Set 1 | albany
# Processing Record 35 of Set 1 | seoul
# Processing Record 36 of Set 1 | punta arenas
# Processing Record 37 of Set 1 | kapaa
# Processing Record 38 of Set 1 | tobane
# Processing Record 39 of Set 1 | lakes entrance
# Processing Record 40 of Set 1 | chokurdakh
# Processing Record 41 of Set 1 | verkhnetulomskiy
# Processing Record 42 of Set 1 | zhangjiakou
# Processing Record 43 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 44 of Set 1 | ruatoria
# City not found. Skipping...
# Processing Record 45 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 1 | hasaki
# Processing Record 47 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 48 of Set 1 | mataura
# Processing Record 49 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 50 of Set 1 | alta floresta
# Processing Record 1 of Set 2 | pevek
# Processing Record 2 of Set 2 | srednekolymsk
# Processing Record 3 of Set 2 | belaya gora
# Processing Record 4 of Set 2 | cape town
# Processing Record 5 of Set 2 | avarua
# Processing Record 6 of Set 2 | ribeira grande
# Processing Record 7 of Set 2 | pochutla
# Processing Record 8 of Set 2 | natal
# Processing Record 9 of Set 2 | ushuaia
# Processing Record 10 of Set 2 | akdepe
# Processing Record 11 of Set 2 | labutta
# City not found. Skipping...
# Processing Record 12 of Set 2 | ibirama
# Processing Record 13 of Set 2 | liniere
# City not found. Skipping...
# Processing Record 14 of Set 2 | mar del plata
# Processing Record 15 of Set 2 | cap malheureux
# Processing Record 16 of Set 2 | hirara
# Processing Record 17 of Set 2 | krasnaya gora
# Processing Record 18 of Set 2 | ishigaki
# Processing Record 19 of Set 2 | portland
# Processing Record 20 of Set 2 | hunza
# City not found. Skipping...
# Processing Record 21 of Set 2 | yanan
# City not found. Skipping...
# Processing Record 22 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 2 | tasiilaq
# Processing Record 24 of Set 2 | iqaluit
# Processing Record 25 of Set 2 | tiksi
# Processing Record 26 of Set 2 | nouadhibou
# Processing Record 27 of Set 2 | narsaq
# Processing Record 28 of Set 2 | wattegama
# Processing Record 29 of Set 2 | peleduy
# Processing Record 30 of Set 2 | jalu
# Processing Record 31 of Set 2 | castro
# Processing Record 32 of Set 2 | racine
# Processing Record 33 of Set 2 | khatanga
# Processing Record 34 of Set 2 | meadow lake
# Processing Record 35 of Set 2 | lebu
# Processing Record 36 of Set 2 | longyearbyen
# Processing Record 37 of Set 2 | yellowknife
# Processing Record 38 of Set 2 | te anau
# Processing Record 39 of Set 2 | hofn
# Processing Record 40 of Set 2 | chuy
# Processing Record 41 of Set 2 | caravelas
# Processing Record 42 of Set 2 | bluff
# Processing Record 43 of Set 2 | georgetown
# Processing Record 44 of Set 2 | gereykhanovskoye
# Processing Record 45 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 46 of Set 2 | canyon lake
# Processing Record 47 of Set 2 | barrow
# Processing Record 48 of Set 2 | ayan
# Processing Record 49 of Set 2 | victoria
# Processing Record 50 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 1 of Set 3 | pacific grove
# Processing Record 2 of Set 3 | sharhorod
# Processing Record 3 of Set 3 | tuatapere
# Processing Record 4 of Set 3 | sao joao da barra
# Processing Record 5 of Set 3 | shizukuishi
# Processing Record 6 of Set 3 | hithadhoo
# Processing Record 7 of Set 3 | talnakh
# Processing Record 8 of Set 3 | fortuna
# Processing Record 9 of Set 3 | lorengau
# Processing Record 10 of Set 3 | mugur-aksy
# Processing Record 11 of Set 3 | esperance
# Processing Record 12 of Set 3 | nuuk
# Processing Record 13 of Set 3 | dongsheng
# Processing Record 14 of Set 3 | sfantu gheorghe
# Processing Record 15 of Set 3 | new norfolk
# Processing Record 16 of Set 3 | lumberton
# Processing Record 17 of Set 3 | half moon bay
# Processing Record 18 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 19 of Set 3 | butaritari
# Processing Record 20 of Set 3 | hobart
# Processing Record 21 of Set 3 | sioux lookout
# Processing Record 22 of Set 3 | ouesso
# Processing Record 23 of Set 3 | cayenne
# Processing Record 24 of Set 3 | corrente
# Processing Record 25 of Set 3 | mahebourg
# Processing Record 26 of Set 3 | isangel
# Processing Record 27 of Set 3 | abu kamal
# Processing Record 28 of Set 3 | vega de alatorre
# Processing Record 29 of Set 3 | taltal
# Processing Record 30 of Set 3 | carnarvon
# Processing Record 31 of Set 3 | matara
# Processing Record 32 of Set 3 | merrill
# Processing Record 33 of Set 3 | geraldton
# Processing Record 34 of Set 3 | bengkulu
# Processing Record 35 of Set 3 | teguise
# Processing Record 36 of Set 3 | sorong
# Processing Record 37 of Set 3 | mama
# Processing Record 38 of Set 3 | arraial do cabo
# Processing Record 39 of Set 3 | erenhot
# Processing Record 40 of Set 3 | mehamn
# Processing Record 41 of Set 3 | bassar
# Processing Record 42 of Set 3 | pandan niog
# Processing Record 43 of Set 3 | constitucion
# Processing Record 44 of Set 3 | samarai
# Processing Record 45 of Set 3 | deputatskiy
# Processing Record 46 of Set 3 | guerrero negro
# Processing Record 47 of Set 3 | upernavik
# Processing Record 48 of Set 3 | horasan
# Processing Record 49 of Set 3 | torbay
# Processing Record 50 of Set 3 | vozuca
# Processing Record 1 of Set 4 | northam
# Processing Record 2 of Set 4 | qaqortoq
# Processing Record 3 of Set 4 | puerto ayora
# Processing Record 4 of Set 4 | verkhnevilyuysk
# Processing Record 5 of Set 4 | klaksvik
# Processing Record 6 of Set 4 | bambous virieux
# Processing Record 7 of Set 4 | presidente epitacio
# Processing Record 8 of Set 4 | leningradskiy
# Processing Record 9 of Set 4 | oskarshamn
# Processing Record 10 of Set 4 | gualeguay
# Processing Record 11 of Set 4 | carballo
# Processing Record 12 of Set 4 | dingle
# Processing Record 13 of Set 4 | dovbysh
# Processing Record 14 of Set 4 | komsomolskiy
# Processing Record 15 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 16 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 17 of Set 4 | yudong
# Processing Record 18 of Set 4 | chumikan
# Processing Record 19 of Set 4 | pisco
# Processing Record 20 of Set 4 | hihifo
# City not found. Skipping...
# Processing Record 21 of Set 4 | freistadt
# Processing Record 22 of Set 4 | san lawrenz
# Processing Record 23 of Set 4 | tayshet
# Processing Record 24 of Set 4 | uspenskaya
# Processing Record 25 of Set 4 | green river
# Processing Record 26 of Set 4 | point fortin
# Processing Record 27 of Set 4 | champerico
# Processing Record 28 of Set 4 | paamiut
# Processing Record 29 of Set 4 | yagodnoye
# Processing Record 30 of Set 4 | nha trang
# Processing Record 31 of Set 4 | gold coast
# Processing Record 32 of Set 4 | nikolayevsk-na-amure
# Processing Record 33 of Set 4 | nikolskoye
# Processing Record 34 of Set 4 | junin
# Processing Record 35 of Set 4 | prince george
# Processing Record 36 of Set 4 | vardo
# Processing Record 37 of Set 4 | kahului
# Processing Record 38 of Set 4 | cabo san lucas
# Processing Record 39 of Set 4 | pedernales
# Processing Record 40 of Set 4 | san patricio
# Processing Record 41 of Set 4 | ahuimanu
# Processing Record 42 of Set 4 | severo-kurilsk
# Processing Record 43 of Set 4 | harper
# Processing Record 44 of Set 4 | sexsmith
# Processing Record 45 of Set 4 | gat
# Processing Record 46 of Set 4 | high prairie
# Processing Record 47 of Set 4 | kodiak
# Processing Record 48 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 49 of Set 4 | bengkalis
# City not found. Skipping...
# Processing Record 50 of Set 4 | mount gambier
# Processing Record 1 of Set 5 | ancud
# Processing Record 2 of Set 5 | araras
# Processing Record 3 of Set 5 | mount isa
# Processing Record 4 of Set 5 | vila velha
# Processing Record 5 of Set 5 | azimur
# City not found. Skipping...
# Processing Record 6 of Set 5 | juifang
# City not found. Skipping...
# Processing Record 7 of Set 5 | hillsboro
# Processing Record 8 of Set 5 | cherskiy
# Processing Record 9 of Set 5 | hoi an
# Processing Record 10 of Set 5 | stephenville
# Processing Record 11 of Set 5 | clyde river
# Processing Record 12 of Set 5 | maragheh
# Processing Record 13 of Set 5 | araouane
# Processing Record 14 of Set 5 | alamosa
# Processing Record 15 of Set 5 | nekhayevskiy
# Processing Record 16 of Set 5 | san fernando
# Processing Record 17 of Set 5 | gobabis
# Processing Record 18 of Set 5 | antofagasta
# Processing Record 19 of Set 5 | saint george
# Processing Record 20 of Set 5 | axim
# Processing Record 21 of Set 5 | asau
# Processing Record 22 of Set 5 | los llanos de aridane
# Processing Record 23 of Set 5 | caconda
# Processing Record 24 of Set 5 | luganville
# Processing Record 25 of Set 5 | saldanha
# Processing Record 26 of Set 5 | souillac
# Processing Record 27 of Set 5 | ketchikan
# Processing Record 28 of Set 5 | ballina
# Processing Record 29 of Set 5 | hinesville
# Processing Record 30 of Set 5 | luderitz
# Processing Record 31 of Set 5 | opuwo
# Processing Record 32 of Set 5 | savalou
# Processing Record 33 of Set 5 | mayo
# Processing Record 34 of Set 5 | ilulissat
# Processing Record 35 of Set 5 | tongren
# Processing Record 36 of Set 5 | tilichiki
# Processing Record 37 of Set 5 | candolim
# Processing Record 38 of Set 5 | yar-sale
# Processing Record 39 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 5 | tautira
# Processing Record 41 of Set 5 | hohhot
# Processing Record 42 of Set 5 | kovdor
# Processing Record 43 of Set 5 | yantarnyy
# Processing Record 44 of Set 5 | alanya
# Processing Record 45 of Set 5 | grindavik
# Processing Record 46 of Set 5 | saint-philippe
# Processing Record 47 of Set 5 | husavik
# Processing Record 48 of Set 5 | marawi
# Processing Record 49 of Set 5 | bilibino
# Processing Record 50 of Set 5 | zarubino
# Processing Record 1 of Set 6 | qaanaaq
# Processing Record 2 of Set 6 | altay
# Processing Record 3 of Set 6 | tocopilla
# Processing Record 4 of Set 6 | anadyr
# Processing Record 5 of Set 6 | nabire
# Processing Record 6 of Set 6 | hongan
# City not found. Skipping...
# Processing Record 7 of Set 6 | tecolotlan
# Processing Record 8 of Set 6 | vila franca do campo
# Processing Record 9 of Set 6 | canico
# Processing Record 10 of Set 6 | pacifica
# Processing Record 11 of Set 6 | east london
# Processing Record 12 of Set 6 | sarkand
# Processing Record 13 of Set 6 | aguia branca
# Processing Record 14 of Set 6 | san cristobal
# Processing Record 15 of Set 6 | batemans bay
# Processing Record 16 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 6 | kruisfontein
# Processing Record 18 of Set 6 | mufulira
# Processing Record 19 of Set 6 | okha
# Processing Record 20 of Set 6 | denpasar
# Processing Record 21 of Set 6 | cidreira
# Processing Record 22 of Set 6 | freeport
# Processing Record 23 of Set 6 | sola
# Processing Record 24 of Set 6 | tiznit
# Processing Record 25 of Set 6 | ullapool
# Processing Record 26 of Set 6 | vallenar
# Processing Record 27 of Set 6 | kirakira
# Processing Record 28 of Set 6 | ikorodu
# Processing Record 29 of Set 6 | lata
# Processing Record 30 of Set 6 | hualmay
# Processing Record 31 of Set 6 | union
# Processing Record 32 of Set 6 | nanga eboko
# Processing Record 33 of Set 6 | norman wells
# Processing Record 34 of Set 6 | saint-joseph
# Processing Record 35 of Set 6 | nsanje
# Processing Record 36 of Set 6 | ferme-neuve
# Processing Record 37 of Set 6 | port-gentil
# Processing Record 38 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 39 of Set 6 | lompoc
# Processing Record 40 of Set 6 | novyy urengoy
# Processing Record 41 of Set 6 | aflu
# City not found. Skipping...
# Processing Record 42 of Set 6 | padang
# Processing Record 43 of Set 6 | nome
# Processing Record 44 of Set 6 | poum
# Processing Record 45 of Set 6 | gisborne
# Processing Record 46 of Set 6 | coihueco
# Processing Record 47 of Set 6 | burgeo
# Processing Record 48 of Set 6 | ponta do sol
# Processing Record 49 of Set 6 | russell
# Processing Record 50 of Set 6 | saskylakh
# Processing Record 1 of Set 7 | killybegs
# Processing Record 2 of Set 7 | porto novo
# Processing Record 3 of Set 7 | synya
# Processing Record 4 of Set 7 | barra patuca
# Processing Record 5 of Set 7 | zhanatas
# City not found. Skipping...
# Processing Record 6 of Set 7 | black forest
# Processing Record 7 of Set 7 | north bend
# Processing Record 8 of Set 7 | skjold
# Processing Record 9 of Set 7 | kosa
# Processing Record 10 of Set 7 | sokol
# Processing Record 11 of Set 7 | lasa
# Processing Record 12 of Set 7 | bardiyah
# Processing Record 13 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 14 of Set 7 | hamilton
# Processing Record 15 of Set 7 | bathsheba
# Processing Record 16 of Set 7 | tuktoyaktuk
# Processing Record 17 of Set 7 | dundee
# Processing Record 18 of Set 7 | manzhouli
# Processing Record 19 of Set 7 | ahipara
# Processing Record 20 of Set 7 | tchamba
# Processing Record 21 of Set 7 | olafsvik
# Processing Record 22 of Set 7 | aksu
# Processing Record 23 of Set 7 | bintulu
# Processing Record 24 of Set 7 | kavaratti
# Processing Record 25 of Set 7 | sur
# Processing Record 26 of Set 7 | shchelyayur
# City not found. Skipping...
# Processing Record 27 of Set 7 | luxeuil-les-bains
# Processing Record 28 of Set 7 | madang
# Processing Record 29 of Set 7 | san francisco
# Processing Record 30 of Set 7 | shimanovsk
# Processing Record 31 of Set 7 | llangefni
# Processing Record 32 of Set 7 | antalaha
# Processing Record 33 of Set 7 | lagoa
# Processing Record 34 of Set 7 | ilinskiy
# Processing Record 35 of Set 7 | camargo
# Processing Record 36 of Set 7 | lagos
# Processing Record 37 of Set 7 | saint-pierre
# Processing Record 38 of Set 7 | shahr-e kord
# Processing Record 39 of Set 7 | camacha
# Processing Record 40 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 41 of Set 7 | bassano
# Processing Record 42 of Set 7 | san andres
# Processing Record 43 of Set 7 | provideniya
# Processing Record 44 of Set 7 | bandarbeyla
# Processing Record 45 of Set 7 | amazar
# Processing Record 46 of Set 7 | horodnytsya
# Processing Record 47 of Set 7 | marzuq
# Processing Record 48 of Set 7 | kieta
# Processing Record 49 of Set 7 | touho
# Processing Record 50 of Set 7 | san quintin
# Processing Record 1 of Set 8 | zhangye
# Processing Record 2 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 3 of Set 8 | faanui
# Processing Record 4 of Set 8 | kimbe
# Processing Record 5 of Set 8 | sarangani
# Processing Record 6 of Set 8 | kaitangata
# Processing Record 7 of Set 8 | nyurba
# Processing Record 8 of Set 8 | guiyang
# Processing Record 9 of Set 8 | tombouctou
# Processing Record 10 of Set 8 | green valley
# Processing Record 11 of Set 8 | corsicana
# Processing Record 12 of Set 8 | rio grande
# Processing Record 13 of Set 8 | bobonong
# City not found. Skipping...
# Processing Record 14 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 8 | praia da vitoria
# Processing Record 17 of Set 8 | say
# Processing Record 18 of Set 8 | ulladulla
# Processing Record 19 of Set 8 | gbarnga
# Processing Record 20 of Set 8 | cururupu
# Processing Record 21 of Set 8 | maloshuyka
# City not found. Skipping...
# Processing Record 22 of Set 8 | salinopolis
# Processing Record 23 of Set 8 | tabou
# Processing Record 24 of Set 8 | haines junction
# Processing Record 25 of Set 8 | at-bashi
# Processing Record 26 of Set 8 | monte patria
# Processing Record 27 of Set 8 | vasterhaninge
# Processing Record 28 of Set 8 | saint-georges
# Processing Record 29 of Set 8 | sandwick
# Processing Record 30 of Set 8 | blythe
# Processing Record 31 of Set 8 | derzhavinsk
# Processing Record 32 of Set 8 | valle de allende
# Processing Record 33 of Set 8 | egvekinot
# Processing Record 34 of Set 8 | tambura
# Processing Record 35 of Set 8 | flinders
# Processing Record 36 of Set 8 | tromso
# Processing Record 37 of Set 8 | meulaboh
# Processing Record 38 of Set 8 | glasgow
# Processing Record 39 of Set 8 | barranca
# Processing Record 40 of Set 8 | sechelt
# Processing Record 41 of Set 8 | shirokaya rechka
# Processing Record 42 of Set 8 | kangalassy
# Processing Record 43 of Set 8 | esperantinopolis
# Processing Record 44 of Set 8 | vanavara
# Processing Record 45 of Set 8 | lazaro cardenas
# Processing Record 46 of Set 8 | kutum
# Processing Record 47 of Set 8 | rawson
# Processing Record 48 of Set 8 | hirado
# Processing Record 49 of Set 8 | krasnoselkup
# Processing Record 50 of Set 8 | jacareacanga
# Processing Record 1 of Set 9 | tomatlan
# Processing Record 2 of Set 9 | palmer
# Processing Record 3 of Set 9 | coihaique
# Processing Record 4 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 5 of Set 9 | yulara
# Processing Record 6 of Set 9 | kindersley
# Processing Record 7 of Set 9 | balkanabat
# Processing Record 8 of Set 9 | codrington
# Processing Record 9 of Set 9 | el prat de llobregat
# Processing Record 10 of Set 9 | virginia beach
# Processing Record 11 of Set 9 | santa isabel do rio negro
# Processing Record 12 of Set 9 | goundam
# Processing Record 13 of Set 9 | rovaniemi
# Processing Record 14 of Set 9 | hammerfest
# Processing Record 15 of Set 9 | saint-paul
# Processing Record 16 of Set 9 | artyk
# City not found. Skipping...
# Processing Record 17 of Set 9 | izumo
# Processing Record 18 of Set 9 | majene
# Processing Record 19 of Set 9 | sagua de tanamo
# Processing Record 20 of Set 9 | posadas
# Processing Record 21 of Set 9 | price
# Processing Record 22 of Set 9 | yangshe
# Processing Record 23 of Set 9 | dafeng
# Processing Record 24 of Set 9 | namatanai
# Processing Record 25 of Set 9 | gallup
# Processing Record 26 of Set 9 | macusani
# Processing Record 27 of Set 9 | sibu
# Processing Record 28 of Set 9 | asfi
# Processing Record 29 of Set 9 | vavuniya
# Processing Record 30 of Set 9 | sobolevo
# Processing Record 31 of Set 9 | iskateley
# Processing Record 32 of Set 9 | taoudenni
# Processing Record 33 of Set 9 | ouegoa
# Processing Record 34 of Set 9 | tigil
# Processing Record 35 of Set 9 | klyuchi
# Processing Record 36 of Set 9 | waipawa
# Processing Record 37 of Set 9 | gedo
# Processing Record 38 of Set 9 | butembo
# Processing Record 39 of Set 9 | pangnirtung
# Processing Record 40 of Set 9 | mezen
# Processing Record 41 of Set 9 | huilong
# Processing Record 42 of Set 9 | clarence town
# Processing Record 43 of Set 9 | babushkin
# Processing Record 44 of Set 9 | snasa
# Processing Record 45 of Set 9 | aswan
# Processing Record 46 of Set 9 | farafangana
# Processing Record 47 of Set 9 | istisu
# Processing Record 48 of Set 9 | shagonar
# Processing Record 49 of Set 9 | alvorada
# Processing Record 50 of Set 9 | prykolotne
# Processing Record 1 of Set 10 | rio gallegos
# Processing Record 2 of Set 10 | pasinler
# Processing Record 3 of Set 10 | tuy hoa
# Processing Record 4 of Set 10 | bayir
# Processing Record 5 of Set 10 | bairiki
# Processing Record 6 of Set 10 | temaraia
# City not found. Skipping...
# Processing Record 7 of Set 10 | lavrentiya
# Processing Record 8 of Set 10 | kaseda
# Processing Record 9 of Set 10 | riaba
# City not found. Skipping...
# Processing Record 10 of Set 10 | peruibe
# Processing Record 11 of Set 10 | arona
# Processing Record 12 of Set 10 | bantou
# Processing Record 13 of Set 10 | frutal
# Processing Record 14 of Set 10 | magistralnyy
# Processing Record 15 of Set 10 | katsuura
# Processing Record 16 of Set 10 | najran
# Processing Record 17 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 18 of Set 10 | urumqi
# Processing Record 19 of Set 10 | goderich
# Processing Record 20 of Set 10 | ostrovnoy
# Processing Record 21 of Set 10 | amahai
# Processing Record 22 of Set 10 | obihiro
# Processing Record 23 of Set 10 | jaguariaiva
# Processing Record 24 of Set 10 | miraflores
# Processing Record 25 of Set 10 | muros
# Processing Record 26 of Set 10 | myanaung
# Processing Record 27 of Set 10 | sibolga
# Processing Record 28 of Set 10 | itaporanga
# Processing Record 29 of Set 10 | masallatah
# Processing Record 30 of Set 10 | nemuro
# Processing Record 31 of Set 10 | itoman
# Processing Record 32 of Set 10 | acapulco
# Processing Record 33 of Set 10 | birsk
# Processing Record 34 of Set 10 | manta
# Processing Record 35 of Set 10 | faya
# Processing Record 36 of Set 10 | lucapa
# Processing Record 37 of Set 10 | dunedin
# Processing Record 38 of Set 10 | mbandaka
# Processing Record 39 of Set 10 | bam
# Processing Record 40 of Set 10 | penzance
# Processing Record 41 of Set 10 | surt
# Processing Record 42 of Set 10 | dutlwe
# Processing Record 43 of Set 10 | brignoles
# Processing Record 44 of Set 10 | varkkallai
# Processing Record 45 of Set 10 | gorno-altaysk
# Processing Record 46 of Set 10 | fomboni
# Processing Record 47 of Set 10 | pine bluff
# Processing Record 48 of Set 10 | bladel
# Processing Record 49 of Set 10 | turtas
# Processing Record 50 of Set 10 | kambove
# Processing Record 1 of Set 11 | rincon
# Processing Record 2 of Set 11 | yeppoon
# Processing Record 3 of Set 11 | tateyama
# Processing Record 4 of Set 11 | gemena
# Processing Record 5 of Set 11 | strezhevoy
# Processing Record 6 of Set 11 | urengoy
# Processing Record 7 of Set 11 | xining
# Processing Record 8 of Set 11 | petropavl
# Processing Record 9 of Set 11 | bambanglipuro
# Processing Record 10 of Set 11 | yishui
# Processing Record 11 of Set 11 | henties bay
# Processing Record 12 of Set 11 | chapais
# Processing Record 13 of Set 11 | veraval
# Processing Record 14 of Set 11 | uromi
# Processing Record 15 of Set 11 | turukhansk
# Processing Record 16 of Set 11 | tessalit
# Processing Record 17 of Set 11 | eyl
# Processing Record 18 of Set 11 | kaduqli
# Processing Record 19 of Set 11 | porbandar
# Processing Record 20 of Set 11 | pingliang
# Processing Record 21 of Set 11 | sorland
# Processing Record 22 of Set 11 | akureyri
# Processing Record 23 of Set 11 | korla
# Processing Record 24 of Set 11 | nhulunbuy
# Processing Record 25 of Set 11 | talagang
# Processing Record 26 of Set 11 | nikel
# Processing Record 27 of Set 11 | bethel
# Processing Record 28 of Set 11 | imbituba
# Processing Record 29 of Set 11 | gao
# Processing Record 30 of Set 11 | moron
# Processing Record 31 of Set 11 | marabba
# Processing Record 32 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 33 of Set 11 | pilar
# Processing Record 34 of Set 11 | bonavista
# Processing Record 35 of Set 11 | maraba
# Processing Record 36 of Set 11 | darnah
# Processing Record 37 of Set 11 | hambantota
# Processing Record 38 of Set 11 | brae
# Processing Record 39 of Set 11 | port lincoln
# Processing Record 40 of Set 11 | williamsburg
# Processing Record 41 of Set 11 | lodwar
# Processing Record 42 of Set 11 | westport
# Processing Record 43 of Set 11 | lensk
# Processing Record 44 of Set 11 | cerro punta
# Processing Record 45 of Set 11 | saint-francois
# Processing Record 46 of Set 11 | khash
# Processing Record 47 of Set 11 | pijijiapan
# Processing Record 48 of Set 11 | gondanglegi
# Processing Record 49 of Set 11 | sabana grande
# Processing Record 50 of Set 11 | desna
# Processing Record 1 of Set 12 | deqing
# Processing Record 2 of Set 12 | kresna
# Processing Record 3 of Set 12 | gazojak
# Processing Record 4 of Set 12 | bowen
# Processing Record 5 of Set 12 | makokou
# Processing Record 6 of Set 12 | rizia
# Processing Record 7 of Set 12 | lydenburg
# Processing Record 8 of Set 12 | kishi
# Processing Record 9 of Set 12 | babanusah
# City not found. Skipping...
# Processing Record 10 of Set 12 | bitung
# Processing Record 11 of Set 12 | salalah
# Processing Record 12 of Set 12 | den helder
# Processing Record 13 of Set 12 | lukovetskiy
# Processing Record 14 of Set 12 | whitehorse
# Processing Record 15 of Set 12 | sabang
# Processing Record 16 of Set 12 | puerto colombia
# Processing Record 17 of Set 12 | sept-iles
# Processing Record 18 of Set 12 | iralaya
# Processing Record 19 of Set 12 | fort wellington
# Processing Record 20 of Set 12 | muisne
# Processing Record 21 of Set 12 | escanaba
# Processing Record 22 of Set 12 | maua
# Processing Record 23 of Set 12 | port-cartier
# Processing Record 24 of Set 12 | tazovskiy
# Processing Record 25 of Set 12 | saint-augustin
# Processing Record 26 of Set 12 | belle fourche
# Processing Record 27 of Set 12 | pirenopolis
# Processing Record 28 of Set 12 | erzin
# Processing Record 29 of Set 12 | zhigansk
# Processing Record 30 of Set 12 | zhuhai
# Processing Record 31 of Set 12 | kissidougou
# Processing Record 32 of Set 12 | le moule
# Processing Record 33 of Set 12 | san jose
# Processing Record 34 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 35 of Set 12 | huntington
# Processing Record 36 of Set 12 | iquitos
# Processing Record 37 of Set 12 | aklavik
# Processing Record 38 of Set 12 | noumea
# Processing Record 39 of Set 12 | port hardy
# Processing Record 40 of Set 12 | alpharetta
# Processing Record 41 of Set 12 | sao gabriel da cachoeira
# Processing Record 42 of Set 12 | ivanava
# Processing Record 43 of Set 12 | kaniama
# Processing Record 44 of Set 12 | kismayo
# Processing Record 45 of Set 12 | bushehr
# Processing Record 46 of Set 12 | morant bay
# Processing Record 47 of Set 12 | taicheng
# Processing Record 48 of Set 12 | urusha
# Processing Record 49 of Set 12 | ngunguru
# Processing Record 50 of Set 12 | karaton
# Processing Record 1 of Set 13 | bereda
# Processing Record 2 of Set 13 | placido de castro
# Processing Record 3 of Set 13 | shar
# Processing Record 4 of Set 13 | jabiru
# City not found. Skipping...
# Processing Record 5 of Set 13 | khandyga
# Processing Record 6 of Set 13 | dongli
# Processing Record 7 of Set 13 | adrar
# Processing Record 8 of Set 13 | cockburn town
# Processing Record 9 of Set 13 | miyako
# Processing Record 10 of Set 13 | crixas
# Processing Record 11 of Set 13 | plettenberg bay
# Processing Record 12 of Set 13 | teya
# Processing Record 13 of Set 13 | jibuti
# Processing Record 14 of Set 13 | santa cruz
# Processing Record 15 of Set 13 | bethanien
# Processing Record 16 of Set 13 | santa rosa
# Processing Record 17 of Set 13 | ornskoldsvik
# Processing Record 18 of Set 13 | puerto madryn
# Processing Record 19 of Set 13 | mabaruma
# Processing Record 20 of Set 13 | muriti
# Processing Record 21 of Set 13 | port augusta
# Processing Record 22 of Set 13 | rodrigues alves
# Processing Record 23 of Set 13 | fairbanks
# Processing Record 24 of Set 13 | kaoma
# Processing Record 25 of Set 13 | general roca
# Processing Record 26 of Set 13 | agadir
# Processing Record 27 of Set 13 | giyani
# Processing Record 28 of Set 13 | brownwood
# Processing Record 29 of Set 13 | inta
# Processing Record 30 of Set 13 | vostok
# Processing Record 31 of Set 13 | pemangkat
# Processing Record 32 of Set 13 | vastervik
# City not found. Skipping...
# Processing Record 33 of Set 13 | petatlan
# Processing Record 34 of Set 13 | solnechnyy
# Processing Record 35 of Set 13 | safford
# Processing Record 36 of Set 13 | rio claro
# Processing Record 37 of Set 13 | mouzouras
# Processing Record 38 of Set 13 | aki
# Processing Record 39 of Set 13 | mitu
# Processing Record 40 of Set 13 | bilma
# Processing Record 41 of Set 13 | linxia
# Processing Record 42 of Set 13 | bosaso
# Processing Record 43 of Set 13 | williams lake
# Processing Record 44 of Set 13 | zabaykalsk
# Processing Record 45 of Set 13 | kiruna
# Processing Record 46 of Set 13 | innisfail
# Processing Record 47 of Set 13 | beringovskiy
# Processing Record 48 of Set 13 | nizhniy tsasuchey
# Processing Record 49 of Set 13 | capreol
# Processing Record 50 of Set 13 | novopetrovskoye
# Processing Record 1 of Set 14 | trowbridge
# Processing Record 2 of Set 14 | sataua
# City not found. Skipping...
# Processing Record 3 of Set 14 | kiama
# Processing Record 4 of Set 14 | santo amaro das brotas
# Processing Record 5 of Set 14 | baie-comeau
# Processing Record 6 of Set 14 | qobustan
# Processing Record 7 of Set 14 | staraya poltavka
# Processing Record 8 of Set 14 | kamaishi
# Processing Record 9 of Set 14 | rabat
# Processing Record 10 of Set 14 | antsohihy
# Processing Record 11 of Set 14 | visby
# Processing Record 12 of Set 14 | la ronge
# Processing Record 13 of Set 14 | buraydah
# Processing Record 14 of Set 14 | pauini
# Processing Record 15 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 16 of Set 14 | mogadishu
# Processing Record 17 of Set 14 | mahibadhoo
# Processing Record 18 of Set 14 | verkhnyaya inta
# Processing Record 19 of Set 14 | serenje
# Processing Record 20 of Set 14 | stoyba
# City not found. Skipping...
# Processing Record 21 of Set 14 | paveh
# Processing Record 22 of Set 14 | papetoai
# Processing Record 23 of Set 14 | cape canaveral
# Processing Record 24 of Set 14 | praxedis guerrero
# Processing Record 25 of Set 14 | soyo
# Processing Record 26 of Set 14 | birjand
# Processing Record 27 of Set 14 | conde
# Processing Record 28 of Set 14 | harbour breton
# Processing Record 29 of Set 14 | manado
# Processing Record 30 of Set 14 | urucui
# Processing Record 31 of Set 14 | qandala
# Processing Record 32 of Set 14 | wonthaggi
# Processing Record 33 of Set 14 | dudinka
# Processing Record 34 of Set 14 | winona
# Processing Record 35 of Set 14 | skibbereen
# Processing Record 36 of Set 14 | haapiti
# Processing Record 37 of Set 14 | port hedland
# Processing Record 38 of Set 14 | shingu
# Processing Record 39 of Set 14 | sassandra
# Processing Record 40 of Set 14 | felipe carrillo puerto
# Processing Record 41 of Set 14 | saint anthony
# Processing Record 42 of Set 14 | okahandja
# Processing Record 43 of Set 14 | karakendzha
# City not found. Skipping...
# Processing Record 44 of Set 14 | agadez
# Processing Record 45 of Set 14 | rocha
# Processing Record 46 of Set 14 | uray
# Processing Record 47 of Set 14 | exeter
# Processing Record 48 of Set 14 | namibe
# Processing Record 49 of Set 14 | clearwater
# Processing Record 50 of Set 14 | new london
# Processing Record 1 of Set 15 | umea
# Processing Record 2 of Set 15 | porto nacional
# Processing Record 3 of Set 15 | zabol
# Processing Record 4 of Set 15 | chingirlau
# Processing Record 5 of Set 15 | victor harbor
# Processing Record 6 of Set 15 | fort nelson
# Processing Record 7 of Set 15 | seydi
# Processing Record 8 of Set 15 | udachnyy
# Processing Record 9 of Set 15 | karlshamn
# Processing Record 10 of Set 15 | suluq
# Processing Record 11 of Set 15 | pandan
# Processing Record 12 of Set 15 | port pirie
# Processing Record 13 of Set 15 | ippy
# Processing Record 14 of Set 15 | villaviciosa
# Processing Record 15 of Set 15 | ban phai
# Processing Record 16 of Set 15 | visnes
# Processing Record 17 of Set 15 | bristol
# Processing Record 18 of Set 15 | sitka
# Processing Record 19 of Set 15 | port blair
# Processing Record 20 of Set 15 | durban
# Processing Record 21 of Set 15 | utiroa
# City not found. Skipping...
# Processing Record 22 of Set 15 | basna
# Processing Record 23 of Set 15 | marsabit
# Processing Record 24 of Set 15 | pemberton
# Processing Record 25 of Set 15 | asheboro
# Processing Record 26 of Set 15 | riyadh
# Processing Record 27 of Set 15 | metro
# Processing Record 28 of Set 15 | wanning
# Processing Record 29 of Set 15 | mitsamiouli
# Processing Record 30 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 31 of Set 15 | mahaicony
# City not found. Skipping...
# Processing Record 32 of Set 15 | ambodifototra
# City not found. Skipping...
# Processing Record 33 of Set 15 | havelock
# Processing Record 34 of Set 15 | leesburg
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# 0                Atar      MR  20.5169  -13.0499    295.25        17
# 1       Alice Springs      AU -23.7000  133.8833    287.90        77
# 2           Jamestown      US  42.0970  -79.2353    267.77        39
# 3              Livani      LV  56.3543   26.1758    272.71        77
# 4              Mardin      TR  37.3131   40.7436    277.46        43
# 5            Berlevag      NO  70.8578   29.0864    267.12        73
# 6         Sakaiminato      JP  35.5500  133.2333    280.58        63
# 7  Havre-Saint-Pierre      CA  50.2334  -63.5986    258.62        66
# 8             Kavieng      PG  -2.5744  150.7967    300.23        78
# 9          Nanortalik      GL  60.1432  -45.2371    271.50        80
#
#    Cloudiness  Wind Speed        Description
# 0         100        4.05    overcast clouds
# 1           0        2.57          clear sky
# 2         100        1.34    overcast clouds
# 3         100        5.25    overcast clouds
# 4          64        2.60      broken clouds
# 5          75        5.14  light shower snow
# 6         100        9.84    overcast clouds
# 7          10        4.58          clear sky
# 8          96        3.04    overcast clouds
# 9         100        4.21    overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database_Challenge_Del2.csv"

#  Export the City_Data into a CSV.
city_data_df = pd.DataFrame(city_data)

#  city_data_df.to_csv(path_or_buf='cities.csv', index_label='City_ID')
city_data_df.to_csv(path_or_buf='WeatherPy_Database_Challenge_Del_2.csv', index_label='City_ID')

# %% [markdown]
# ### Step 1. Import the WeatherPy_database.csv file.

# %%
city_data_df = pd.read_csv('WeatherPy_Database_Challenge_Del_2.csv')
city_data_df.head()
# Out:
#    City_ID           City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0           Atar      MR  20.5169  -13.0499    295.25        17
# 1        1  Alice Springs      AU -23.7000  133.8833    287.90        77
# 2        2      Jamestown      US  42.0970  -79.2353    267.77        39
# 3        3         Livani      LV  56.3543   26.1758    272.71        77
# 4        4         Mardin      TR  37.3131   40.7436    277.46        43
#
#    Cloudiness  Wind Speed      Description
# 0         100        4.05  overcast clouds
# 1           0        2.57        clear sky
# 2         100        1.34  overcast clouds
# 3         100        5.25  overcast clouds
# 4          64        2.60    broken clouds

# %%
print(city_data_df)
# Out:
#      City_ID           City Country      Lat       Lng  Max Temp  Humidity  \
# 0          0           Atar      MR  20.5169  -13.0499    295.25        17
# 1          1  Alice Springs      AU -23.7000  133.8833    287.90        77
# 2          2      Jamestown      US  42.0970  -79.2353    267.77        39
# 3          3         Livani      LV  56.3543   26.1758    272.71        77
# 4          4         Mardin      TR  37.3131   40.7436    277.46        43
# ..       ...            ...     ...      ...       ...       ...       ...
# 675      675          Metro      ID  -5.1131  105.3067    297.13        90
# 676      676        Wanning      CN  18.8003  110.3967    293.88        91
# 677      677    Mitsamiouli      KM -11.3847   43.2844    300.28        80
# 678      678       Havelock      US  34.8791  -76.9013    281.28        89
# 679      679       Leesburg      US  39.1157  -77.5636    275.42        66
#
#      Cloudiness  Wind Speed      Description
# 0           100        4.05  overcast clouds
# 1             0        2.57        clear sky
# 2           100        1.34  overcast clouds
# 3           100        5.25  overcast clouds
# 4            64        2.60    broken clouds
# ..          ...         ...              ...
# 675         100        1.04  overcast clouds
# 676         100        5.31  overcast clouds
# 677           9        1.03        clear sky
# 678         100        0.89  overcast clouds
# 679         100        3.09       light snow
#
# [680 rows x 10 columns]

# %% [markdown]
# ### Step 2. Prompt the user to enter minimum and maximum temperature criteria

# %%
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 50
# What is the maximum temperature you would like for your trip? 80

# %% [markdown]
# ### Step 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.

# %%
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head()
# Out:
# Empty DataFrame
# Columns: [City_ID, City, Country, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Description]
# Index: []

# %%
print(preferred_cities_df)
# Out:
# Empty DataFrame
# Columns: [City_ID, City, Country, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Description]
# Index: []

# %% [markdown]
# ### Step 4a. Determine if there are any empty rows.

# %%
preferred_cities_df.isnull().count()
# Out:
# City_ID        0
# City           0
# Country        0
# Lat            0
# Lng            0
# Max Temp       0
# Humidity       0
# Cloudiness     0
# Wind Speed     0
# Description    0
# dtype: int64

# %% [markdown]
# ### Step 4b. Drop any empty rows and create a new DataFrame that doesn't have empty rows.

# %%
clean_df = preferred_cities_df.dropna()
clean_df.isnull().sum()
# Out:
# City_ID        0.0
# City           0.0
# Country        0.0
# Lat            0.0
# Lng            0.0
# Max Temp       0.0
# Humidity       0.0
# Cloudiness     0.0
# Wind Speed     0.0
# Description    0.0
# dtype: float64

# %%
print(clean_df)
# Out:
# Empty DataFrame
# Columns: [City_ID, City, Country, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Description]
# Index: []

# %% [markdown]
# ### Step 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.

# %%
hotel_df = clean_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()
print(hotel_df)
# Out:
# Empty DataFrame
# Columns: [City, Country, Max Temp, Lat, Lng]
# Index: []

# %% [markdown]
# ### Step 5b. Create a new column "Hotel Name"

# %%
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
# Empty DataFrame
# Columns: [City, Country, Max Temp, Lat, Lng, Hotel Name]
# Index: []

# %% [markdown]
# ### Step 6a. Set parameters to search for hotels with 5000 meters

# %%
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# %% [markdown]
# ### Step 6b. Iterate through the hotel DataFrame.

# %%
for index, row in hotel_df.iterrows():
# Out:
#   File "C:\Users\M221912\AppData\Local\Temp/ipykernel_1384/4193690893.py", line 1
#     for index, row in hotel_df.iterrows():
#                                           ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# ### Step 6c. Get latitude and longitude from DataFrame

# %%
lat = "Lat"
lng = "Lng"
params["location"] = f"{lat},{lng}"

# %% [markdown]
# ### Step 6d. Set up the base URL for the Google Directions API to get JSON data.

# %%
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# %% [markdown]
# ### Step 6e. Make request and retrieve the JSON data from the search.

# %%
hotels = requests.get(base_url, params=params).json()

# %% [markdown]
# ### Step 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.

# %%
try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
except:
        print("Hotel not found... skipping.")
# Out:
# Hotel not found... skipping.

# %% [markdown]
# ### Step 7. Drop the rows where there is no Hotel Name.

# %%
hotel_df.head(10)
clean_hotel_df = hotel_df.dropna()

# %% [markdown]
# ### Step 8a.Create the output File (CSV)

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_vacation.csv"

# %% [markdown]
# ### Step 8b. Export the City_Data into a csv

# %%
clean_hotel_df.to_csv(output_data_file, index_label="City_ID")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1384/88197092.py in <module>
# ----> 1 clean_hotel_df.to_csv(output_data_file, index_label="City_ID")
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3480             doublequote=doublequote,
#    3481             escapechar=escapechar,
# -> 3482             storage_options=storage_options,
#    3483         )
#    3484
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1103             formatter=self.fmt,
#    1104         )
# -> 1105         csv_formatter.save()
#    1106
#    1107         if created_buffer:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     241             errors=self.errors,
#     242             compression=self.compression,
# --> 243             storage_options=self.storage_options,
#     244         ) as handles:
#     245
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Weather_Database/WeatherPy_vacation.csv'

# %% [markdown]
# ### Step 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.

# %%
info_box_template = """

"""

# %% [markdown]
# ### Step 10a. Get the data from each row and add it to the formatting template and store the data in a list.

# %%
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# %% [markdown]
# ### Step 10b. Get the latitude and longitude from each row and store in a new DataFrame.

# %%
locations = clean_hotel_df[["Lat", "Lng"]]

# %% [markdown]
# ### Step 11a. Add a marker layer for each city to the map.

# %% [markdown]
# ### Step 11b. Display the figure
